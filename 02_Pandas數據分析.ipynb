# %% [markdown]
# # Pandas數據分析
#
# 今天介紹資料分析近來很紅的 pandas 套件, 作者是 Wes McKinney。Python 會成為一個數據分析的熱門語言, 和 pandas 的出現也有相當的關係。
#
# 但是 pandas 雖然功能強, 但有些地方沒那麼直覺, 有時會讓大家以為是個深奧的套件。其實你大約可以把 pandas 想成「Python 的 Excel」, 但是功能更強、更有彈性、也有更多的可能性。
#
# 下面介紹個基本上就是把 pandas 當 Excel 學的影片, 相信大家會覺得很親切。<br>
# https://youtu.be/9d5-Ti6onew

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# ## 1 開始使用 `pandas`
#
# 首先我們來讀入一個 CSV 檔, 這裡有個「假的」學測成績, 叫 `grades.csv` 我們來練習一下。

# %%
df = pd.read_csv("data/grades.csv")

# %% [markdown]
# 用 `df` 是標準的叫法 (雖然這名稱我們隨便取也可以), 意思是 Data Frame, 這是 `pandas` 兩大資料結構之一。我們可以把 Data Frame 想成一張表格 (雖然其實可以是很多張表格)。
#
# 我們來看看我們 `df` 的前五筆資料。

# %%
type(df)  #資料型態
# Out:
# pandas.core.frame.DataFrame

# %%
df.head()
# Out:
#     姓名  國文  英文  數學  自然  社會
# 0  劉俊安   9  10  15  10  13
# 1  胡玉華  10  10  10   8   9
# 2  黃淑婷  13  15   8  11  14
# 3  陳上紫  10  10   8   9  14
# 4  崔靜成  13  12  14  12  13

# %% [markdown]
# 如果你曾經手動讀入 CSV 檔, 就知道這省了多少事 (雖然我個人還挺喜歡純手動帶進 CSV)。

# %% [markdown]
# #### Excel 檔也可以快速讀入
#
# 不只 CSV 檔, 很多資料檔案, 像 Excel 檔都很容易在 `pandas` 完成。使用法是這樣:
#
#     df2 = pd.read_excel('filename.xls', 'sheetname')
#
# 其中 sheetname 那裡要放工作表的名稱, 如果是中文的最好改成英文。

# %% [markdown]
# ## 2 Pandas 基本資料結構
#
# Pandas 有兩個基本資料結構:
#
# * <b style="color:red;">DataFrame</b>: 可以想成一個表格。
# * <b style="color:red;">Series</b>: 表格的某一列、某一行, 基本上就是我們以前的 list 或 array
#
# 一個 DataFrame, 我們有 `index` (列的名稱), `columns` (行的名稱)。
#
# #### DataFrame
#
# ![DataFrame 的結構](images/indexcol.png)

# %% [markdown]
# #### Series
#
# 剛剛說 series 大概就是一個 list, 一個 array。其實更精準的說, 其實是一個有 "index" 的 array。
#
# DataFrame 的每一行或每一列其實也都是一個 series。我們來看個例子, 例如所有同學的國文成績, 就是一個 series。

# %%
df["國文"]
# Out:
# 0      9
# 1     10
# 2     13
# 3     10
# 4     13
#       ..
# 95     9
# 96     8
# 97    14
# 98    15
# 99     9
# Name: 國文, Length: 100, dtype: int64

# %% [markdown]
# 在 Python 3 中, 我們終於可以和英文同步, 用這種很炫的方式叫出所有國文成績。

# %%
df.國文
# Out:
# 0      9
# 1     10
# 2     13
# 3     10
# 4     13
#       ..
# 95     9
# 96     8
# 97    14
# 98    15
# 99     9
# Name: 國文, Length: 100, dtype: int64

# %% [markdown]
# #### 資料畫出來
#
# 要畫個圖很容易。

# %%
df["國文"].plot()

# %% [markdown]
# 當然, 在這個例子中, 其實畫 histogram 圖更有意義一點。

# %%
df["國文"].hist(bins=15)

# %% [markdown]
# ## 3 一些基本的資料分析

# %% [markdown]
# 算平均。

# %%
df.國文.mean()
# Out:
# 11.39

# %% [markdown]
# 算標準差。

# %%
df.國文.std()
# Out:
# 2.1968526614594834

# %% [markdown]
# 不如就該算的都幫我們算算...

# %%
df.describe()
# Out:
#                國文          英文          數學         自然         社會
# count  100.000000  100.000000  100.000000  100.00000  100.00000
# mean    11.390000   11.380000   11.570000   11.03000   11.83000
# std      2.196853    2.273164    2.310516    2.21772    2.48655
# min      8.000000    8.000000    8.000000    8.00000    8.00000
# 25%      9.000000    9.000000   10.000000    9.00000    9.00000
# 50%     11.000000   11.000000   11.000000   11.00000   12.00000
# 75%     13.000000   13.000000   14.000000   13.00000   14.00000
# max     15.000000   15.000000   15.000000   15.00000   15.00000

# %% [markdown]
# 有時我們很愛看的相關係數矩陣。

# %%
#相關係數
df.corr()
# Out:
#           國文        英文        數學        自然        社會
# 國文  1.000000  0.160158 -0.310899 -0.110236 -0.028421
# 英文  0.160158  1.000000  0.025656  0.113929 -0.063512
# 數學 -0.310899  0.025656  1.000000  0.014371  0.041651
# 自然 -0.110236  0.113929  0.014371  1.000000 -0.156594
# 社會 -0.028421 -0.063512  0.041651 -0.156594  1.000000

# %% [markdown]
# 只算兩科間的相關係數當然也可以。

# %%
df.國文.corr(df.英文)  #相關係數corr()，括號內也要是df.科目
# Out:
# 0.16015801596684315

# %% [markdown]
# ## 4 增加一行

# %% [markdown]
# ### 【技巧】
#
# 我們增加一行, 加入總級分。

# %%
df["總級分"] = df.sum(axis=1)
df.head()
# Out:
#     姓名  國文  英文  數學  自然  社會  總級分
# 0  劉俊安   9  10  15  10  13   57
# 1  胡玉華  10  10  10   8   9   47
# 2  黃淑婷  13  15   8  11  14   61
# 3  陳上紫  10  10   8   9  14   51
# 4  崔靜成  13  12  14  12  13   64

# %%
df["加權"] = df.國文 +df.英文*1.25 + df.數學*1.5
df.head()
# Out:
#     姓名  國文  英文  數學  自然  社會  總級分     加權
# 0  劉俊安   9  10  15  10  13   57  44.00
# 1  胡玉華  10  10  10   8   9   47  37.50
# 2  黃淑婷  13  15   8  11  14   61  43.75
# 3  陳上紫  10  10   8   9  14   51  34.50
# 4  崔靜成  13  12  14  12  13   64  49.00

# %% [markdown]
# ### 【技巧】
#
# 有計算的當然也可以的。

# %%
# Out:
#     姓名  國文  英文  數學  自然  社會  總級分  加權
# 0  劉俊安   9  10  15  10  13   57  49
# 1  胡玉華  10  10  10   8   9   47  40
# 2  黃淑婷  13  15   8  11  14   61  44
# 3  陳上紫  10  10   8   9  14   51  36
# 4  崔靜成  13  12  14  12  13   64  53

# %% [markdown]
# ## 5 排序和 index 重設

# %% [markdown]
# ### 【重點】排序的方法
#
# 我們依總級分來排序。

# %%
df.sort_values("總級分",ascending = False).head()
# Out:
#      姓名  國文  英文  數學  自然  社會  總級分     加權
# 80  施雅鈴  13  15  12  13  13   66  49.75
# 12  李正偉  11  15  11  14  15   66  46.25
# 54  陳怡潔  15  15   9  15  11   65  47.25
# 25  蔡亦瑄  13  13  14  13  12   65  50.25
# 57  胡淳茜  12  15  14  13  11   65  51.75

# %% [markdown]
# ### 【重點】排序的方法
#
# 加權分最高, 同分才看總級分

# %%
# 有好幾個條件做排序!
df2 = df.sort_values(by=["加權","總級分"],ascending = False)
df2.head()
# Out:
#      姓名  國文  英文  數學  自然  社會  總級分     加權
# 73  吳志遠  13  15  15   8   8   59  54.25
# 57  胡淳茜  12  15  14  13  11   65  51.75
# 36  詹威德  12  13  15  10  14   64  50.75
# 48  陳怡婷  15  14  12   9  15   65  50.50
# 25  蔡亦瑄  13  13  14  13  12   65  50.25

# %% [markdown]
# ### 【重點】重設 index

# %%
df2.index = range(1,101)  #指定新的索引index值
df2.head()
# Out:
#     姓名  國文  英文  數學  自然  社會  總級分     加權
# 1  吳志遠  13  15  15   8   8   59  54.25
# 2  胡淳茜  12  15  14  13  11   65  51.75
# 3  詹威德  12  13  15  10  14   64  50.75
# 4  陳怡婷  15  14  12   9  15   65  50.50
# 5  蔡亦瑄  13  13  14  13  12   65  50.25

# %% [markdown]
# ## 6 篩出我們要的資料
#
# 基本上和 NumPy 的 array 篩法很像。

# %% [markdown]
# ### 【重點】
#
# 找出數學滿級分同學。

# %%
df2[df2.數學 == 15]
# Out:
#      姓名  國文  英文  數學  自然  社會  總級分     加權
# 1   吳志遠  13  15  15   8   8   59  54.25
# 3   詹威德  12  13  15  10  14   64  50.75
# 7   李士賢  10  14  15  13  13   65  50.00
# 11  曾怡君  11  12  15  13  14   65  48.50
# 14  林哲法  14   9  15  10  14   62  47.75
# 15  葉儀依   9  13  15   8  14   59  47.75
# 17  陳竹伯  10  12  15  10  14   61  47.50
# 23  周育霖   9  12  15  13  12   61  46.50
# 25  張雅彬  10  11  15  12   8   56  46.25
# 30  芮秋辛  11  10  15  10   8   54  46.00
# 42  胡勝傑   8  11  15  10  15   59  44.25
# 48  劉俊安   9  10  15  10  13   57  44.00
# 67  段冠廷   9   8  15  12  15   59  41.50

# %% [markdown]
# ### 【重點】
#
# 找出數學和英文都滿級分的同學。要注意 `and` 要用 `&`, `or` 要用 `|`。每個條件一定要加弧號。

# %%
#要注意 and 要用 &, or 要用 |。每個條件一定要加弧號
df2[(df2.數學 == 15) & (df2.英文 == 15)]
# Out:
#     姓名  國文  英文  數學  自然  社會  總級分     加權
# 1  吳志遠  13  15  15   8   8   59  54.25

# %%
df2[(df2.數學 == 15) | (df2.英文 == 15)]
# Out:
#      姓名  國文  英文  數學  自然  社會  總級分     加權
# 1   吳志遠  13  15  15   8   8   59  54.25
# 2   胡淳茜  12  15  14  13  11   65  51.75
# 3   詹威德  12  13  15  10  14   64  50.75
# 7   李士賢  10  14  15  13  13   65  50.00
# 9   施雅鈴  13  15  12  13  13   66  49.75
# 11  曾怡君  11  12  15  13  14   65  48.50
# 14  林哲法  14   9  15  10  14   62  47.75
# 15  葉儀依   9  13  15   8  14   59  47.75
# 17  陳竹伯  10  12  15  10  14   61  47.50
# 18  陳怡潔  15  15   9  15  11   65  47.25
# 21  郭雅惠  10  15  12  11   9   57  46.75
# 23  周育霖   9  12  15  13  12   61  46.50
# 24  李正偉  11  15  11  14  15   66  46.25
# 25  張雅彬  10  11  15  12   8   56  46.25
# 26  王佳蓉  14  15   9   9   8   55  46.25
# 30  芮秋辛  11  10  15  10   8   54  46.00
# 42  胡勝傑   8  11  15  10  15   59  44.25
# 43  林士茜  12  15   9   9  13   58  44.25
# 44  林意珍   9  15  11  13   9   57  44.25
# 48  劉俊安   9  10  15  10  13   57  44.00
# 52  黃淑婷  13  15   8  11  14   61  43.75
# 67  段冠廷   9   8  15  12  15   59  41.50

# %% [markdown]
# ## 7 刪除一行或一列

# %% [markdown]
# ### 【重點】刪掉一行
#
# 我們來刪掉總級分的那行。

# %%
df2.drop("總級分",axis=1)
# Out:
#       姓名  國文  英文  數學  自然  社會     加權
# 1    吳志遠  13  15  15   8   8  54.25
# 2    胡淳茜  12  15  14  13  11  51.75
# 3    詹威德  12  13  15  10  14  50.75
# 4    陳怡婷  15  14  12   9  15  50.50
# 5    蔡亦瑄  13  13  14  13  12  50.25
# ..   ...  ..  ..  ..  ..  ..    ...
# 96   陳上紫  10  10   8   9  14  34.50
# 97   林金鳳   8   9  10  10   8  34.25
# 98   胡凱琳  10   8   9   9  15  33.50
# 99   梁慧君   9   8   8   8  12  31.00
# 100  吳文伯   8   8   8  15  12  30.00
#
# [100 rows x 7 columns]

# %% [markdown]
# df2並沒有被修改到

# %%
df2
# Out:
#       姓名  國文  英文  數學  自然  社會  總級分     加權
# 1    吳志遠  13  15  15   8   8   59  54.25
# 2    胡淳茜  12  15  14  13  11   65  51.75
# 3    詹威德  12  13  15  10  14   64  50.75
# 4    陳怡婷  15  14  12   9  15   65  50.50
# 5    蔡亦瑄  13  13  14  13  12   65  50.25
# ..   ...  ..  ..  ..  ..  ..  ...    ...
# 96   陳上紫  10  10   8   9  14   51  34.50
# 97   林金鳳   8   9  10  10   8   45  34.25
# 98   胡凱琳  10   8   9   9  15   51  33.50
# 99   梁慧君   9   8   8   8  12   45  31.00
# 100  吳文伯   8   8   8  15  12   51  30.00
#
# [100 rows x 8 columns]

# %% [markdown]
# ### 【重點】改變原有的 DataFrame
#
# 我們會發現 `pandas` 很多動作都沒有更改原有的 DataFrame, 真的要改要加入
#
#     inplace=True

# %%
df2.drop("總級分",axis=1, inplace = True)
df2
# Out:
#      姓名  國文  英文  數學  自然  社會     加權
# 73  吳志遠  13  15  15   8   8  54.25
# 57  胡淳茜  12  15  14  13  11  51.75
# 36  詹威德  12  13  15  10  14  50.75
# 48  陳怡婷  15  14  12   9  15  50.50
# 25  蔡亦瑄  13  13  14  13  12  50.25
# ..  ...  ..  ..  ..  ..  ..    ...
# 3   陳上紫  10  10   8   9  14  34.50
# 7   林金鳳   8   9  10  10   8  34.25
# 84  胡凱琳  10   8   9   9  15  33.50
# 18  梁慧君   9   8   8   8  12  31.00
# 38  吳文伯   8   8   8  15  12  30.00
#
# [100 rows x 7 columns]

# %% [markdown]
# ### 【重點】刪掉一列
#
# 刪掉列就是指定要刪去的 index。

# %%
df2.head()
# Out:
#      姓名  國文  英文  數學  自然  社會     加權
# 73  吳志遠  13  15  15   8   8  54.25
# 57  胡淳茜  12  15  14  13  11  51.75
# 36  詹威德  12  13  15  10  14  50.75
# 48  陳怡婷  15  14  12   9  15  50.50
# 25  蔡亦瑄  13  13  14  13  12  50.25

# %%
df2.index = range(1,101)
df2.head()
# Out:
#     姓名  國文  英文  數學  自然  社會     加權
# 1  吳志遠  13  15  15   8   8  54.25
# 2  胡淳茜  12  15  14  13  11  51.75
# 3  詹威德  12  13  15  10  14  50.75
# 4  陳怡婷  15  14  12   9  15  50.50
# 5  蔡亦瑄  13  13  14  13  12  50.25

# %%
df2.drop(2)
# Out:
#       姓名  國文  英文  數學  自然  社會     加權
# 1    吳志遠  13  15  15   8   8  54.25
# 3    詹威德  12  13  15  10  14  50.75
# 4    陳怡婷  15  14  12   9  15  50.50
# 5    蔡亦瑄  13  13  14  13  12  50.25
# 6    童心怡  13  13  14   8  13  50.25
# ..   ...  ..  ..  ..  ..  ..    ...
# 96   陳上紫  10  10   8   9  14  34.50
# 97   林金鳳   8   9  10  10   8  34.25
# 98   胡凱琳  10   8   9   9  15  33.50
# 99   梁慧君   9   8   8   8  12  31.00
# 100  吳文伯   8   8   8  15  12  30.00
#
# [99 rows x 7 columns]

# %% [markdown]
# ### 【重點】刪掉一列
#
# 通常刪掉符合條件的比較合理 (注意是找到要刪掉的部份, 再找出相對的 index)。

# %%
df2[df2.姓名 =="胡淳茜"] #先找到目標
# Out:
#     姓名  國文  英文  數學  自然  社會     加權
# 2  胡淳茜  12  15  14  13  11  51.75

# %%
#他刪除的邏輯是以找到index後，才去執行drop
df2.drop(df2[df2.姓名 =="胡淳茜"].index)
# Out:
#       姓名  國文  英文  數學  自然  社會     加權
# 1    吳志遠  13  15  15   8   8  54.25
# 3    詹威德  12  13  15  10  14  50.75
# 4    陳怡婷  15  14  12   9  15  50.50
# 5    蔡亦瑄  13  13  14  13  12  50.25
# 6    童心怡  13  13  14   8  13  50.25
# ..   ...  ..  ..  ..  ..  ..    ...
# 96   陳上紫  10  10   8   9  14  34.50
# 97   林金鳳   8   9  10  10   8  34.25
# 98   胡凱琳  10   8   9   9  15  33.50
# 99   梁慧君   9   8   8   8  12  31.00
# 100  吳文伯   8   8   8  15  12  30.00
#
# [99 rows x 7 columns]

# %% [markdown]
# ## 8 真實股價資料
#
# 有個從 `Pandas` 獨立出來的套件叫 `pandas-datareader`, 幾經波折, 先是 Yahoo! 的財務資料不能用, 後來又是 Google 的資料不能用, 不過至少現在看來 Yahoo! 還可以使用。
#
# 安裝 `pandas-datareader` 就標準 `conda` 安裝:
#
#     conda install pandas-datareader
#
# 如果裝過, 但很久沒更新就用:
#
#     conda update pandas-datareader

# %% [markdown]
# ### 【例子】 分析 Apple 股價

# %%
import pandas_datareader as pdr
df = pdr.get_data_yahoo('AAPL')
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-4-62156263d35f> in <module>
# ----> 1 import pandas_datareader as pdr
#       2 df = pdr.get_data_yahoo('AAPL')
#
# ModuleNotFoundError: No module named 'pandas_datareader'

# %%
# 為防止網路有問題, 我們把這個檔案以 aapl.csv 存起來, 可以這樣讀入。
df = pd.read_csv('data/aapl.csv', index_col="Date")

# %%
df.head()
# Out:
#                  Open       High        Low      Close  Adj Close     Volume
# Date
# 2009-12-31  30.447144  30.478571  30.080000  30.104286  26.986492   88102700
# 2010-01-04  30.490000  30.642857  30.340000  30.572857  27.406532  123432400
# 2010-01-05  30.657143  30.798571  30.464285  30.625713  27.453915  150476200
# 2010-01-06  30.625713  30.747143  30.107143  30.138571  27.017223  138040000
# 2010-01-07  30.250000  30.285715  29.864286  30.082857  26.967278  119282800

# %% [markdown]
# #### 只要最後 300 個交易日!

# %%
df = df[-300:]  #輸入-300
df
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2016-10-03  112.709999  113.050003  112.279999  112.519997  110.173546
# 2016-10-04  113.059998  114.309998  112.629997  113.000000  110.643539
# 2016-10-05  113.400002  113.660004  112.690002  113.050003  110.692505
# 2016-10-06  113.699997  114.339996  113.129997  113.889999  111.514984
# 2016-10-07  114.309998  114.559998  113.510002  114.059998  111.681435
# ...                ...         ...         ...         ...         ...
# 2017-12-04  172.479996  172.619995  169.630005  169.800003  169.800003
# 2017-12-05  169.059998  171.520004  168.399994  169.639999  169.639999
# 2017-12-06  167.500000  170.199997  166.460007  169.009995  169.009995
# 2017-12-07  169.029999  170.440002  168.910004  169.320007  169.320007
# 2017-12-08  170.490005  171.000000  168.820007  169.369995  169.369995
#
#               Volume
# Date
# 2016-10-03  21701800
# 2016-10-04  29736800
# 2016-10-05  21453100
# ...

# %% [markdown]
# #### 20 日的移動平均

# %%
df.Close.plot()

# %%
df.Close.rolling(20).mean().plot()  #移動平均線

# %%
df.Close.plot()
df.Close.rolling(20).mean().plot()

# %% [markdown]
# #### 20 日和 60 日的移動平均

# %%
df.Close.plot(legend=True)
df.Close.rolling(20).mean().plot(label="$MA_{20}$",legend=True)
df.Close.rolling(60).mean().plot(label="$MA_{60}$",legend=True)
df.Close.rolling(120).mean().plot(label="$MA_{120}$",legend=True)

#label="$MA_{20}$"裡面， $ $只是表示讓字體變斜的 ; _{ }是讓字體變小

# %% [markdown]
# #### 準備做預測
#
# 我們用個非常天真的模型...
#
# ![天真股票模型](images/naive.png)
#
# 網路上說這是線性的 (可能嗎)!

# %%
close = df.Close.values
len(close)
# Out:
# 300

# %%
x=close[:-1]  #從頭開始，-1表最後一個
print(x)
len(x)
# Out:
# [112.519997 113.       113.050003 113.889999 114.059998 116.050003
#  116.300003 117.339996 116.980003 117.629997 117.550003 117.470001
#  117.120003 117.059998 116.599998 117.650002 118.25     115.589996
#  114.480003 113.720001 113.540001 111.489998 111.589996 109.830002
#  108.839996 110.410004 111.059998 110.879997 107.790001 108.43
#  105.709999 107.110001 109.989998 109.949997 110.059998 111.730003
#  111.800003 111.230003 111.790001 111.57     111.459999 110.519997
#  109.489998 109.900002 109.110001 109.949997 111.029999 112.120003
#  113.949997 113.300003 115.190002 115.190002 115.82     115.970001
#  116.639999 116.949997 117.059998 116.290001 116.519997 117.260002
#  116.760002 116.730003 115.82     116.150002 116.019997 116.610001
#  117.910004 118.989998 119.110001 119.75     119.25     119.040001
#  120.       119.989998 119.779999 120.       120.080002 119.970001
#  121.879997 121.940002 121.949997 121.629997 121.349998 128.75
# ...

# %%
y=close[1:] 
print(y)
len(y)
# Out:
# [113.       113.050003 113.889999 114.059998 116.050003 116.300003
#  117.339996 116.980003 117.629997 117.550003 117.470001 117.120003
#  117.059998 116.599998 117.650002 118.25     115.589996 114.480003
#  113.720001 113.540001 111.489998 111.589996 109.830002 108.839996
#  110.410004 111.059998 110.879997 107.790001 108.43     105.709999
#  107.110001 109.989998 109.949997 110.059998 111.730003 111.800003
#  111.230003 111.790001 111.57     111.459999 110.519997 109.489998
#  109.900002 109.110001 109.949997 111.029999 112.120003 113.949997
#  113.300003 115.190002 115.190002 115.82     115.970001 116.639999
#  116.949997 117.059998 116.290001 116.519997 117.260002 116.760002
#  116.730003 115.82     116.150002 116.019997 116.610001 117.910004
#  118.989998 119.110001 119.75     119.25     119.040001 120.
#  119.989998 119.779999 120.       120.080002 119.970001 121.879997
#  121.940002 121.949997 121.629997 121.349998 128.75     128.529999
# ...

# %%
import matplotlib.pyplot as plt 
plt.scatter(x,y)

# %% [markdown]
# 哦, 真的有點像線性的, 我們之後用線性迴歸試試看。

# %% [markdown]
# ## 9 手工打造一個 DataFrame*
#
# 有時我們用手工打造一個簡單的 DataFrame, 可以更理解整個結構。其實很容易, 一個 DataFrame 基本上就包含兩個主要部份:
#
# * 資料本身: 通常一個二維陣列 (矩陣)
# * 行、列的名稱
#
# 我們來個簡單的小例子。

# %%
mydata = np.random.randn(4,3)

# %%
mydata
# Out:
# array([[-0.38728253, -0.15153912,  0.76216478],
#        [-1.07970162,  0.43438601, -0.45283185],
#        [-0.34834485,  0.39032571, -0.66772769],
#        [-1.55082001, -1.58538955,  2.88275962]])

# %% [markdown]
# 把行列的名字放進去, 就成一個 DataFrame。我們列的部份先讓 Python 自己產生。

# %%
df2 = pd.DataFrame(mydata, columns=list("ABC"))

# %%
df2
# Out:
#           A         B         C
# 0 -0.387283 -0.151539  0.762165
# 1 -1.079702  0.434386 -0.452832
# 2 -0.348345  0.390326 -0.667728
# 3 -1.550820 -1.585390  2.882760

# %% [markdown]
# #### 兩個表格上下貼起來
#
# 我們再來生一個 DataFrame, 再「貼」起來。

# %%
df3 = pd.DataFrame(np.random.randn(3,3), columns=list("ABC"))

# %%
df3
# Out:
#           A         B         C
# 0  1.118326 -0.772457 -0.457182
# 1 -0.418937 -1.997281 -1.806858
# 2 -1.526630  0.311816 -0.556917

# %%
df4 = pd.concat([df2,df3],axis=0)

# %%
df4
# Out:
#           A         B         C
# 0 -0.387283 -0.151539  0.762165
# 1 -1.079702  0.434386 -0.452832
# 2 -0.348345  0.390326 -0.667728
# 3 -1.550820 -1.585390  2.882760
# 0  1.118326 -0.772457 -0.457182
# 1 -0.418937 -1.997281 -1.806858
# 2 -1.526630  0.311816 -0.556917

# %% [markdown]
# 前面我們弄得亂七八糟的 index 重設一下。

# %%
df4.index = range(len(df4))

# %%
df4
# Out:
#           A         B         C
# 0 -0.387283 -0.151539  0.762165
# 1 -1.079702  0.434386 -0.452832
# 2 -0.348345  0.390326 -0.667728
# 3 -1.550820 -1.585390  2.882760
# 4  1.118326 -0.772457 -0.457182
# 5 -0.418937 -1.997281 -1.806858
# 6 -1.526630  0.311816 -0.556917

# %% [markdown]
# #### 横向的貼

# %%
df5 = pd.concat([df2,df3],axis=1)

# %% [markdown]
# 等等, 這大小好像不太對也可以嗎? 答案是可以的!

# %%
df5
# Out:
#           A         B         C         A         B         C
# 0 -0.387283 -0.151539  0.762165  1.118326 -0.772457 -0.457182
# 1 -1.079702  0.434386 -0.452832 -0.418937 -1.997281 -1.806858
# 2 -0.348345  0.390326 -0.667728 -1.526630  0.311816 -0.556917
# 3 -1.550820 -1.585390  2.882760       NaN       NaN       NaN

# %% [markdown]
# #### 大一點的例子
#
# 我們來做前面「假的」學測資料。首先要有「假的」同學名單, 如果有興趣產生很多名字, 可以用這個服務。
#
# [中文姓名產生器](http://www.richyli.com/name/index.asp)

# %%
df_names = pd.read_csv('data/names.csv',names =["姓名"])

# %%
df_names.head()
# Out:
#     姓名
# 0  羅雅慧
# 1  王紹尹
# 2  黃季坤
# 3  許正書
# 4  張鈞蓮

# %%
c = pd.DataFrame(np.random.randint(6,16,(100,5)),
                        columns=['國文','英文','數學','社會','自然'])

# %%
df_grades
# Out:
#     國文  英文  數學  社會  自然
# 0    9   9  14   6  11
# 1    7  10   7  14  10
# 2   14  13   8   7   8
# 3   10  10   8  12  15
# 4   13  10  13  10   8
# ..  ..  ..  ..  ..  ..
# 95  13  10   8   6   6
# 96   8  12  10   6  12
# 97   9   6  13  12  12
# 98   7   7  10  13   7
# 99  13  14  12   6  15
#
# [100 rows x 5 columns]

# %% [markdown]
# 另存一個檔案

# %%
df_grades.to_csv('data/grade2.csv',index =0)  
#index =0的意思是不把index當成一個欄位存進去

# %%
df_name2 = pd.read_csv("data/grade2.csv")
df_name2
# Out:
#     國文  英文  數學  社會  自然
# 0    9   9  14   6  11
# 1    7  10   7  14  10
# 2   14  13   8   7   8
# 3   10  10   8  12  15
# 4   13  10  13  10   8
# ..  ..  ..  ..  ..  ..
# 95  13  10   8   6   6
# 96   8  12  10   6  12
# 97   9   6  13  12  12
# 98   7   7  10  13   7
# 99  13  14  12   6  15
#
# [100 rows x 5 columns]

# %%
#
