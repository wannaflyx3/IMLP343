# %% [markdown]
# # `Matplotlib` 資料視覺化

# %% [markdown]
# `matplotlib` 幾乎是標準 Python 畫圖套件了! 在有 `matplotlib` 之前, Python 要畫圖不那麼方便, 和 Python 很多套件一樣, 有許多方案, 但各家有不同的優缺點, 也沒有一套是大家都在用的。
#
# 而 `matplotlib` 仿 Matlab 式的畫圖方式, 讓很多人很快入手、並且功能相當完整。原作者是 John D. Hunter, 和很多 Python 的套件作者一樣, 他有博士學位。非常令人遺憾的是他在 2012 年因大腸直腸癌治療併發症過逝, 過逝時才 44 歲!

# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
import warnings
warnings.filterwarnings('ignore')
import matplotlib.pyplot as plt
from matplotlib.font_manager import FontProperties
import matplotlib
[f.name for f in matplotlib.font_manager.fontManager.ttflist]
# Out:
# ['STIXGeneral',
#  'DejaVu Serif',
#  'DejaVu Sans Mono',
#  'STIXSizeThreeSym',
#  'STIXGeneral',
#  'STIXGeneral',
#  'STIXSizeOneSym',
#  'STIXSizeFiveSym',
#  'STIXNonUnicode',
#  'cmr10',
#  'DejaVu Sans Display',
#  'cmmi10',
#  'STIXNonUnicode',
#  'STIXSizeFourSym',
#  'cmb10',
#  'DejaVu Sans Mono',
#  'STIXSizeTwoSym',
#  'cmss10',
#  'DejaVu Serif',
#  'STIXNonUnicode',
#  'STIXSizeThreeSym',
#  'STIXSizeFourSym',
#  'STIXGeneral',
#  'STIXSizeOneSym',
#  'DejaVu Sans',
#  'DejaVu Sans',
#  'DejaVu Sans Mono',
#  'DejaVu Sans Mono',
#  'cmex10',
#  'DejaVu Serif',
#  'cmtt10',
#  'DejaVu Sans',
#  'cmsy10',
#  'DejaVu Serif Display',
#  'STIXNonUnicode',
#  'DejaVu Sans',
#  'STIXSizeTwoSym',
#  'DejaVu Serif',
#  'Franklin Gothic Medium',
#  'Kristen ITC',
#  'Perpetua',
#  'Segoe UI',
#  'Gill Sans Ultra Bold',
#  'Microsoft JhengHei',
#  'CityBlueprint',
#  'Courier New',
#  'Felix Titling',
#  'Lucida Bright',
#  'Consolas',
#  'Symap',
#  'Lucida Sans Typewriter',
#  'Microsoft Tai Le',
#  'Rockwell Condensed',
#  'BankGothic Md BT',
#  'Bookman Old Style',
#  'Dubai',
#  'Swis721 Blk BT',
#  'Rockwell Extra Bold',
#  'Segoe UI',
#  'Kunstler Script',
#  'Leelawadee UI',
#  'Rockwell',
#  'Segoe UI Historic',
#  'Chiller',
#  'Arial',
#  'STHupo',
#  'Constantia',
#  'Lucida Bright',
#  'Candara',
#  'Modern No. 20',
#  'Dutch801 Rm BT',
#  'Segoe UI Emoji',
#  'Lucida Fax',
#  'Consolas',
#  'Perpetua',
#  'Swis721 BlkEx BT',
#  'Georgia',
#  'Malgun Gothic',
#  'Swis721 Ex BT',
#  'Bookman Old Style',
#  'GothicI',
#  'Segoe UI',
#  'MV Boli',
#  'Bodoni MT',
#  'Forte',
#  'Rockwell Condensed',
#  'Perpetua',
#  'Lucida Sans Typewriter',
#  'Dutch801 Rm BT',
#  'Complex',
#  'Arial',
#  'Century Schoolbook',
#  'Viner Hand ITC',
#  'Goudy Old Style',
#  'Goudy Stout',
#  'Corbel',
#  'Arial',
#  'SuperFrench',
#  'Corbel',
#  'Vijaya',
#  'Calibri',
#  'Lucida Handwriting',
#  'Candara',
#  'Microsoft New Tai Lue',
#  'Lucida Bright',
#  'Microsoft Uighur',
#  'Franklin Gothic Book',
#  'French Script MT',
#  'Myanmar Text',
#  'Perpetua',
#  'Corbel',
#  'Bahnschrift',
#  'Garamond',
#  'Webdings',
#  'Bookman Old Style',
#  'Bell MT',
#  'ItalicC',
#  'Berlin Sans FB Demi',
#  'Poor Richard',
#  'Simplex',
#  'Microsoft Yi Baiti',
#  'Lucida Sans',
#  'Impact',
#  'Proxy 7',
#  'Dubai',
#  'Comic Sans MS',
#  'Californian FB',
#  'CommercialScript BT',
#  'Syastro',
#  'Tw Cen MT',
#  'Eras Demi ITC',
#  'Lucida Sans Typewriter',
#  'Verdana',
#  'MT Extra',
#  'ISOCPEUR',
#  'Franklin Gothic Demi Cond',
#  'Calibri',
#  'Verdana',
#  'Segoe Script',
#  'High Tower Text',
#  'Corbel',
#  'Tempus Sans ITC',
#  'Swis721 Blk BT',
#  'GDT',
#  'Times New Roman',
#  'Vivaldi',
#  'Cambria',
#  'Century Gothic',
#  'Italic',
#  'ISOCP2',
#  'Curlz MT',
#  'Romantic',
#  'Footlight MT Light',
#  'Corbel',
#  'Gill Sans Ultra Bold Condensed',
#  'Swis721 LtEx BT',
#  'Sitka Small',
#  'Blackadder ITC',
#  'Bodoni MT',
#  'Calibri',
#  'ISOCTEUR',
#  'Pristina',
#  'Franklin Gothic Book',
#  'Sitka Small',
#  'Franklin Gothic Heavy',
#  'Courier New',
#  'Matura MT Script Capitals',
#  'Garamond',
#  'Franklin Gothic Medium Cond',
#  'Romantic',
#  'Lucida Fax',
#  'Harrington',
#  'Papyrus',
#  'Segoe UI',
#  'ISOCT',
#  'Segoe UI',
#  'Century Gothic',
#  'Yu Gothic',
#  'Book Antiqua',
#  'Bell MT',
#  'Trebuchet MS',
#  'Dutch801 Rm BT',
#  'Centaur',
#  'LiSu',
#  'Vijaya',
#  'DFKai-SB',
#  'Imprint MT Shadow',
#  'Segoe UI',
#  'Onyx',
#  'RomanD',
#  'Palatino Linotype',
#  'Lucida Sans',
#  'Calisto MT',
#  'Times New Roman',
#  'Swis721 Cn BT',
#  'Agency FB',
#  'Constantia',
#  'SimSun',
#  'Microsoft Uighur',
#  'Microsoft New Tai Lue',
#  'Swis721 Ex BT',
#  'Segoe UI Symbol',
#  'Swis721 BdCnOul BT',
#  'ISOCPEUR',
#  'STXihei',
#  'Leelawadee',
#  'Palace Script MT',
#  'MS Gothic',
#  'Myanmar Text',
#  'Bernard MT Condensed',
#  'Informal Roman',
#  'Monospac821 BT',
#  'Monospac821 BT',
#  'Symbol',
#  'Franklin Gothic Medium',
#  'Lucida Sans Unicode',
#  'Courier New',
#  'MingLiU-ExtB',
#  'Segoe Script',
#  'TechnicBold',
#  'Dutch801 Rm BT',
#  'Perpetua Titling MT',
#  'ISOCTEUR',
#  'Tahoma',
#  'Copperplate Gothic Bold',
#  'SansSerif',
#  'RomanC',
#  'Century',
#  'ISOCT3',
#  'Lucida Console',
#  'Leelawadee UI',
#  'Segoe UI',
#  'Bodoni MT',
#  'SansSerif',
#  'Rockwell',
#  'Copperplate Gothic Light',
#  'Californian FB',
#  'STXingkai',
#  'Colonna MT',
#  'Swis721 Lt BT',
#  'Bradley Hand ITC',
#  'Constantia',
#  'Javanese Text',
#  'Consolas',
#  'Gadugi',
#  'Malgun Gothic',
#  'Eras Bold ITC',
#  'Trebuchet MS',
#  'GreekC',
#  'ROG Fonts',
#  'Nirmala UI',
#  'ScriptC',
#  'STLiti',
#  'Arial',
#  'Proxy 1',
#  'Gigi',
#  'Swis721 Cn BT',
#  'Proxy 4',
#  'AMGDT',
#  'Calibri',
#  'Mistral',
#  'Calisto MT',
#  'Monotype Corsiva',
#  'Microsoft YaHei',
#  'Bodoni MT',
#  'Microsoft Tai Le',
#  'Century Schoolbook',
#  'Constantia',
#  'HoloLens MDL2 Assets',
#  'UniversalMath1 BT',
#  'Gill Sans MT',
#  'Eras Light ITC',
#  'Microsoft PhagsPa',
#  'Georgia',
#  'Tahoma',
#  'Leelawadee',
#  'Swis721 BT',
#  'Elephant',
#  'Trebuchet MS',
#  'AmdtSymbols',
#  'Bodoni MT',
#  'Tw Cen MT Condensed',
#  'CommercialPi BT',
#  'Castellar',
#  'Microsoft Sans Serif',
#  'Vineta BT',
#  'OCR A Extended',
#  'Mongolian Baiti',
#  'Broadway',
#  'Elephant',
#  'CountryBlueprint',
#  'Brush Script MT',
#  'Gill Sans MT',
#  'Yu Gothic',
#  'Rage Italic',
#  'Gill Sans MT Ext Condensed Bold',
#  'Calisto MT',
#  'Comic Sans MS',
#  'MS Reference Sans Serif',
#  'Dubai',
#  'Swis721 BT',
#  'Goudy Old Style',
#  'Perpetua Titling MT',
#  'Symath',
#  'MS Outlook',
#  'Arial',
#  'Parchment',
#  'Swis721 LtCn BT',
#  'Bodoni MT',
#  'MingLiU',
#  'Segoe Print',
#  'Freestyle Script',
#  'Artifakt Element',
#  'Baskerville Old Face',
#  'Segoe UI',
#  'Book Antiqua',
#  'Swis721 BT',
#  'Haettenschweiler',
#  'Agency FB',
#  'Bauhaus 93',
#  'Swis721 BlkOul BT',
#  'Monotxt',
#  'Rockwell',
#  'Arial',
#  'Century Gothic',
#  'Romantic',
#  'Jokerman',
#  'Stencil',
#  'Showcard Gothic',
#  'Bookman Old Style',
#  'Microsoft Himalaya',
#  'Arial',
#  'FZYaoTi',
#  'Niagara Engraved',
#  'Lucida Fax',
#  'Vladimir Script',
#  'Eras Medium ITC',
#  'Yu Gothic',
#  'Tw Cen MT Condensed Extra Bold',
#  'Artifakt Element',
#  'Microsoft JhengHei',
#  'Microsoft PhagsPa',
#  'Artifakt Element',
#  'Franklin Gothic Demi',
#  'AIGDT',
#  'Cambria',
#  'ISOCP',
#  'Marlett',
#  'Bodoni MT',
#  'Calibri',
#  'Ink Free',
#  'Old English Text MT',
#  'Malgun Gothic',
#  'ItalicT',
#  'ISOCP3',
#  'Times New Roman',
#  'Engravers MT',
#  'Arial Rounded MT Bold',
#  'Lucida Sans',
#  'Cambria',
#  'Candara',
#  'STSong',
#  'Bodoni MT',
#  'Technic',
#  'AcadEref',
#  'Proxy 5',
#  'Wingdings 2',
#  'GENISO',
#  'Californian FB',
#  'FZShuTi',
#  'SansSerif',
#  'Verdana',
#  'Leelawadee UI',
#  'Century Schoolbook',
#  'Segoe UI',
#  'Nirmala UI',
#  'Segoe UI',
#  'STZhongsong',
#  'Edwardian Script ITC',
#  'Proxy 9',
#  'Bodoni MT',
#  'Swis721 BlkCn BT',
#  'Garamond',
#  'Arial',
#  'Yu Gothic',
#  'Swis721 Lt BT',
#  'STFangsong',
#  'Bookshelf Symbol 7',
#  'Franklin Gothic Demi',
#  'Proxy 8',
#  'Nirmala UI',
#  'Candara',
#  'Symusic',
#  'Proxy 2',
#  'Ravie',
#  'Gadugi',
#  'Comic Sans MS',
#  'Rockwell',
#  'Georgia',
#  'Dubai',
#  'Script MT Bold',
#  'Century Gothic',
#  'Niagara Solid',
#  'Monospac821 BT',
#  'Tw Cen MT',
#  'Century Schoolbook',
#  'Gabriola',
#  'ISOCT2',
#  'Dutch801 XBd BT',
#  'BankGothic Lt BT',
#  'Palatino Linotype',
#  'Berlin Sans FB',
#  'Bell MT',
#  'Segoe UI',
#  'RomanT',
#  'Swis721 BdOul BT',
#  'Snap ITC',
#  'Tw Cen MT',
#  'GreekS',
#  'Britannic Bold',
#  'EuroRoman',
#  'Gloucester MT Extra Condensed',
#  'Maiandra GD',
#  'ScriptS',
#  'SansSerif',
#  'Monospac821 BT',
#  'STCaiyun',
#  'Palatino Linotype',
#  'Swis721 BT',
#  'Stylus BT',
#  'Wide Latin',
#  'MS Reference Specialty',
#  'Verdana',
#  'Ebrima',
#  'Harlow Solid Italic',
#  'GothicE',
#  'STXinwei',
#  'Swis721 LtCn BT',
#  'Candara',
#  'Arial',
#  'PanRoman',
#  'Wingdings',
#  'Book Antiqua',
#  'Artifakt Element',
#  'Gill Sans MT',
#  'Proxy 6',
#  'Lucida Bright',
#  'GothicG',
#  'SimSun-ExtB',
#  'Microsoft JhengHei',
#  'Microsoft YaHei',
#  'TechnicLite',
#  'Magneto',
#  'Swis721 Cn BT',
#  'Sitka Small',
#  'Candara',
#  'Bodoni MT',
#  'Franklin Gothic Heavy',
#  'Playbill',
#  'Courier New',
#  'Georgia',
#  'Segoe UI',
#  'Segoe Print',
#  'Calibri',
#  'Berlin Sans FB',
#  'High Tower Text',
#  'Ebrima',
#  'Swis721 BlkCn BT',
#  'EuroRoman',
#  'Consolas',
#  'Cambria',
#  'Proxy 3',
#  'YouYuan',
#  'Goudy Old Style',
#  'Gill Sans MT',
#  'Juice ITC',
#  'Sylfaen',
#  'Corbel',
#  'Segoe MDL2 Assets',
#  'Symeteo',
#  'Book Antiqua',
#  'RomanS',
#  'Times New Roman',
#  'Swis721 Cn BT',
#  'Txt',
#  'Wingdings 3',
#  'Palatino Linotype',
#  'Sitka Small',
#  'Lucida Fax',
#  'Bodoni MT',
#  'Calisto MT',
#  'Tw Cen MT',
#  'Tw Cen MT Condensed',
#  'Lucida Calligraphy',
#  'Lucida Sans Typewriter',
#  'Algerian',
#  'STKaiti',
#  'Gill Sans MT Condensed',
#  'Cooper Black',
#  'Trebuchet MS',
#  'Lucida Sans',
#  'Comic Sans MS',
#  'Microsoft YaHei']

# %% [markdown]
# ## 1 畫個函數
#
# 前面說過 `plt.plot` 的基本用法是
#
#     plt.plot(X,Y)
#
# 其中 X, Y 是分別是點 x 座標, y 座標形的的 list 或 array。

# %% [markdown]
# ### 【重點】標準函數畫法
#
# 函數畫圖其實就是描點法, 而且再次用到陣列導向計算的概念。
#
# 我們先牛刀小試, 畫個 $\sin$ 的圖。
#
# $$f(x) = \sin(x)$$

# %% [markdown]
# 先來設個 x 的範圍, 就 -10 到 10, 給 100 個點。

# %%
x = np.linspace(-10,10,100)

# %% [markdown]
# y 自然是 $\sin(x)$。

# %%
y = np.sin(x)

# %% [markdown]
# 畫圖!

# %%
plt.plot(x,y)

# %% [markdown]
# ### 【練習】函數畫圖
#
# 這次我們來畫:
#
# $$f(x) = \frac{\sin(5x)}{1+x^2}$$

# %%
x = np.linspace(0, 10, 200)
x1 = 1+ x**2

y = np.sin(5*x)/x1
plt.plot(x,y)

# %% [markdown]
# ## 2 快速改變風格
#
# 雖然 `matplotlib` 在很辛苦的調校之後也是可以畫美美的圖, 不過它比較是「讓我們快速看到結果」的套件。所以它有些快速基本修飾功能。

# %% [markdown]
# ### 【技巧】快速改變顏色
#
# ![快取色彩](images/color.png)

# %%
x = np.linspace(-10,10,200)
y = np.sinc(x)

plt.plot(x,y,'r')

# %% [markdown]
# ### 【技巧】快速改變線條風格
#
# 快速改變線條風格, 還可和顏色混用。
#
# | 參數 | 說明 |
# |---|---|
# | `--` | dash |
# | `-.` | 點 + dash |
# | `:` | 點點 |
# | `o` | 大點點 |
# | `^` | 三角 |
# | `s` | 方塊 |

# %%
x = np.linspace(-10,10,200)
y = np.cos(x)
plt.plot(x,y,'r-.')

# %% [markdown]
# ## 3 基本的修飾
#
# | 參數 | 說明 |
# |---|---|
# | `alpha` | 透明度 |
# | `color` (`c`)| 顏色 |
# | `linestyle` (`ls`) | 線條風格 |
# | `linewidth` (`lw`) | 線寬 |

# %%
plt.plot(x,y, c='r', lw=4)  #lw = 線寬

# %% [markdown]
# ## 4 如果畫個參數式圖形
#
# 其實參數式圖形基本上也是一堆 x, y 的座標, 只是 x(t), y(t) 都是 t 的函數, 我們可以想成 t 是時間。
#
# 假設我們的
#
# $$ -2\pi \leq t \leq 2\pi$$
#
# 要畫個半徑是 r 的圓, x(t), y(t) 就是這樣:
#
# * $x(t) = r\cos(t)$
# * $y(t) = r\sin(t)$
#
# 我們來試試事情是不是如我們想的這樣...

# %%
r = 3
t = np.linspace(-2*np.pi, 2*np.pi, 200)

# %%
x = r*np.cos(t)
y = r*np.sin(t)

# %%
plt.plot(x, y, lw=3)

# %% [markdown]
# 真的成功了... 等等, `matplotlib` 怎麼畫成橢圓呢? 我們來調整一下。

# %%
ax = plt.gca()  #gca就是get current axis
ax.set_aspect('equal')  #設定成相等
plt.plot(x, y, lw=3)

# %% [markdown]
# 再來我們可以想一下, 如果 r 不是故定的呢? 也就是它會變長變短, 是不是會畫出很多特別的圖呢? 其實很多特別的曲線不過就是找個試合的 r(t), 我們來隨意試試看。

# %%
r = np.sin(8*t)
x = r*np.cos(t)
y = r*np.sin(t)

ax = plt.gca()
ax.set_aspect('equal')
plt.plot(x, y,"r-.",lw=0.5)

# %% [markdown]
# 是不是很有意思呢? 你也可以自己試試不同的變化。

# %% [markdown]
# ## 5 `subplot` 畫多個圖
#
# 我們每次畫圖的時候, `matplotlib` 就弄 1 個 figure 畫圖區出來, 裡面可以有很多子圖, 在 figure 裡叫 axes。目前我們都只有 1 個 figure 內含 1 張圖, 所以都不用設, 現在我想畫 4 張圖時。我們就要先想好「陣式」。
#
# 比如說 2x2 這樣排列的 4 張圖。

# %%
x = np.linspace(0, 10, 100)

plt.subplot(221) # 分成2X2 佔用第一個
plt.plot(x, np.sin(x), c='#e63946', lw=3)

plt.subplot(222) # 分成2X2 佔用第二個
plt.plot(x,np.sin(3*x), c='#7fb069', lw=3)

plt.subplot(223) # 分成2X2 佔用第三個
plt.scatter(x, np.random.randn(100), c='#daa73e', s=50, alpha=0.5)

plt.subplot(224) # 分成2X2 佔用第四個
plt.bar(range(10), np.random.randint(1,30,10), fc='#e55934')
# Out:
# <BarContainer object of 10 artists>

# %%
np.random.randn(5)
# Out:
# array([ 0.7844459 , -0.55319772,  0.14119489, -0.02959525,  0.83959443])

# %% [markdown]
# ## 6 進階色彩*
#
# #### 顏色表示法 1
#
#     c = 'r'
#
# 可以用 blue (b), green (g), red (r), cyan (c), magenta (m), yellow (y), black (k), white (w)
#
#
# #### 顏色表示法 2
#
# 用一個 0 到 1 的數字表灰階, 越大越白。
#
#     c = '0.6'
#
# #### 顏色表示法 3
#
# 網頁常用的標準 16 進位 RGB 表示法。
#
#     c = '#00a676'
#
# 我們怎知哪裡可選顏色呢? 可以用之前彥良介紹的 [Coolors.co](https://coolors.co) 等。
#
# #### 顏色表示法 4
#
# 用 0-1 的數字表 RGB 也可以。
#
#     c=(0.7, 0.4, 1)

# %%
x = np.linspace(-10,10,200)
y = np.sinc(x)
plt.plot(x,y,c='#00a676',alpha=10,lw=0.5)

# %% [markdown]
# ## 7 Marker*
#
# 所謂 'marker' 就是原來的點, 我們特別標示出來, 為了不要讓圖形太複雜, 我們新換個點比較少的例子。

# %%
x = range(20)
y = np.random.randn(20)

# %%
plt.plot(x,y)

# %%
plt.plot(x,y,marker='^')

# %% [markdown]
# #### marker 可以設的參數
#
# | 參數 | 說明 |
# |---|---|
# | `marker` | marker 的風格 |
# | `markeredgecolor` (`mec`) | 邊線顏色 |
# | `markeredgewidth` (`mew`) | 邊線寬度 |
# | `markerfacecolor` (`mfc`) | marker 的顏色 |
# | `markerfacecoloralt` (`mfcalt`) | marker 替換色 |
# | `markersize` (`ms`) | marker 大小 |
# | `markevery` | 隔多少畫一個 marker |

# %%
plt.plot(x, y, c='#6b8fb4', lw=5, marker='o', mfc='#fffa7c', mec="#084c61", mew=3, ms=15)

# %% [markdown]
# 比較奇特的參數是 `markevery`, 這是說我們每多少筆資料要畫一個 marker。為了示範, 我們拿之前的例子來看看。

# %%
x = np.linspace(0, 10, 200)
y = np.sin(5*x) / (1+x**2)
plt.plot(x, y, lw=3, marker='o', ms=10)

# %% [markdown]
# 後面的完完全全連在一起了, 我們現在隔 10 個畫一個 marker 試試。

# %%
plt.plot(x, y, lw=3, marker='o', ms=10, markevery=10)  #markevery=10 就是隔10個點畫一個

# %% [markdown]
# ## 8 bar 風*

# %%
plt.bar(range(1,6), np.random.randint(1,30,5))
# Out:
# <BarContainer object of 5 artists>

# %% [markdown]
# 移一點點。

# %%
plt.bar(np.arange(0.5, 5), np.random.randint(1,30,5))
# Out:
# <BarContainer object of 5 artists>

# %% [markdown]
# #### 雙色的長條圖

# %%
x = np.arange(1,6)
plt.bar(x - 0.4, [3, 10, 8, 12, 6], width=0.4, ec='none', fc='#e63946')
plt.bar(x, [6, 3, 12, 5, 8], width=0.4, ec='none', fc='#7fb069')
# Out:
# <BarContainer object of 5 artists>

# %% [markdown]
# #### 疊加型的資料

# %%
A = np.random.randint(2,15,5)
B = np.random.randint(2,15,5)
C = np.random.randint(2,15,5)

plt.bar(x, A, fc='#e63946', ec='none')
plt.bar(x, B, fc='#7fb069', ec='none',bottom=A)
plt.bar(x, C, fc='#e55934', ec='none',bottom=A+B)
# Out:
# <BarContainer object of 5 artists>

# %%
x1=range(1,4)
a=np.array([10,4,5])
b=np.array([2,2,1])
c=np.array([7,8,9])

plt.bar(x1,a,fc='#e63946')
plt.bar(x1,b,fc='#7fb069',bottom =a)
plt.bar(x1,c,fc='#e55934',bottom =a+b)
# Out:
# <BarContainer object of 3 artists>

# %% [markdown]
# #### 橫放的長條圖

# %%
A = np.random.randint(2,15,5)
plt.barh(x, A, fc='#e63946', ec='none')
# Out:
# <BarContainer object of 5 artists>

# %% [markdown]
# #### 雙向的長條圖

# %%
x = np.arange(0.6,6)
A = np.random.randint(1,15,6)
B = np.random.randint(1,15,6)

plt.barh(x, A, fc='#e63946', ec='none')
plt.barh(x, -B, fc='#7fb069', ec='none')
# Out:
# <BarContainer object of 6 artists>

# %% [markdown]
# ## 9 畫圖區的設定*

# %% [markdown]
# #### 說明文字的標示

# %%
x = np.linspace(-2*np.pi, 2*np.pi, 200)
y = np.sin(x)

# %%
plt.title("My lovely sin function")
plt.xlabel('x-axes')
plt.ylabel('values')
plt.plot(x,y,lw=3,c='r')

# %% [markdown]
# #### 邊界的設定

# %%
plt.plot(x,y,lw=3)
plt.xlim(-6,6)
plt.ylim(-1,1)
# Out:
# (-1, 1)

# %% [markdown]
# #### xticks，設定軸上標籤

# %%
xv = np.linspace(0, 2*np.pi, 100)
yv = np.sin(xv)
plt.plot(xv,yv,lw=3)
plt.xticks([0,np.pi/2,np.pi,3*np.pi/2,2*np.pi],['$0$','$\pi/2$','$\pi$','$3*\pi/2$','$-2\pi$'])
plt.yticks([-1,0,1],['min','mean','max'])
#plt.xticks([位置],[顯示的標值])
# Out:
# ([<matplotlib.axis.YTick at 0x1bdd5272708>,
#   <matplotlib.axis.YTick at 0x1bdd51e1e48>,
#   <matplotlib.axis.YTick at 0x1bdd52be708>],
#  <a list of 3 Text yticklabel objects>)

# %% [markdown]
# # [練習]自己生成測試數據，X軸xticks對應到y軸數值
#
# 例如: 1,2,3,4,5 對應X軸 '甲','乙'...

# %%
from matplotlib.font_manager import FontProperties
plt.rcParams['font.sans-serif'] = ['Microsoft JhengHei'] 

x= range(4)
y = np.random.randint(1,40,4)
plt.bar(x,y)
plt.xticks(x,['甲','乙','丙','丁'])
plt.xlabel('班別')
plt.ylabel('人數')
plt.title('各班人數分布')
# Out:
# Text(0.5, 1.0, '各班人數分布')

# %% [markdown]
# #### 圖例 legend

# %%
x = np.linspace(0, 2*np.pi, 100)
plt.xlim(0,6)
plt.ylim(-1.2,1.2)
plt.plot(x, np.sin(x), lw=3, label='$\sin$')
plt.plot(x, np.cos(x), lw=3, label='$\cos$')
plt.legend()

# %% [raw]
# 可用 `loc` 去設圖例的位置, 依 1, 2, 3, ... 表示。

# %%
plt.xlim(0,6)
plt.ylim(-1.2,1.2)
plt.plot(x, np.sin(x), lw=3, label='$\sin$')
plt.plot(x, np.cos(x), lw=3, label='$\cos$')
plt.legend(loc=1)

# %% [markdown]
# ## 10 取得現在工作中 axes*
#
# 我們有時要設 axes 的背景啦等等的資訊。這時就要取得現在工作中的 axes。這一般有兩種方式, 第一種是設 `subplot` 時可以取得:
#
#     fig, ax = plt.subplot()
#
# 另一種是用 `gca` 函數:
#
#     ax = plt.gca()

# %%
x = np.linspace(-6, 6, 100)
y = np.sin(x)
ax = plt.gca()
ax.set_facecolor('#69b8bb') #背景顏色
ax.set_xlim(-6,6)
ax.set_ylim(-1.2,1.2)
plt.plot(x,y,lw=5,c='white')

# %% [markdown]
# #### 移動 x, y 座標軸

# %%
ax = plt.gca()
ax.set_facecolor('#69b8bb')
ax.set_xlim(-6,6)
ax.set_ylim(-1.2,1.2)

ax.spines['bottom'].set_position(('data',0))
ax.spines['left'].set_position(('data',0))
plt.plot(x,y,lw=5,c='white')

# %% [markdown]
# ## 11 耍寶可愛的 `xkcd`*

# %%
plt.xkcd()  #可愛風格

# %%
x = np.linspace(-5, 5, 200)
y = np.sin(2*x) + 0.2*x
plt.plot(x,y)

# %% [markdown]
# ## 12 `seaborn` 大救星
#
# 雖然 `matplotlib` 幾乎什麼都可以調, 但有些簡單的調整卻要花費很多時間。於是有了許多可以協助 `matplotlib` 變美、變方便的套件出現。最近有個很有名的叫 `seaborn`, 儼然有另一個標準套件的態式。
#
# 最重要的是 `seaborn` 和我們未來要介紹的 `pandas` 配合得非常好, 雖然熊貓和海生的聽來就沒什麼關係...
#
# 我們先來個標準 (又來標準縮寫) 讀入 `seaborn` 的方法。

# %%
import seaborn as sns

# %% [markdown]
# 然後像平常畫個圖。

# %%
sns.set(color_codes=True)

# %%
x = np.linspace(-10,10,200)
y = np.sinc(x)

plt.plot(x,y)

# %% [markdown]
# 傑克, 這真是太神奇了!
#
# 總之, 你根本就直接用原來 `matplotlib` 的指令, 馬上 `seaborn` 就會幫你美化。當然我們還是可以做更多的控制, 詳情請參考
#
# [seaborn 的網站](https://seaborn.github.io/)

# %%
plt.rcdefaults()  #標準形式
